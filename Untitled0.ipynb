# %% [markdown]
# - hello
# - world

# %% [markdown]
# ex prg

# %%
a="kush"
b="praveen"
print(a,b)
# Out:
# kush praveen

# %% [markdown]
# basic syntax code

# %%
print("hello, world") # function type
x=5 # variable assignment
y=10 # no need to declare type
# Out:
# hello, world

# %% [markdown]
# numeric types

# %%
age = 25 # int
heigth = 5.9 # float
complex_num = 3+4j # complex

# %% [markdown]
# string type

# %%
name = "alice"
message ="hello world"

# %% [markdown]
# boolean type

# %%
is_active = True
is_finished = False

# %% [markdown]
# type conversion

# %%
str_number ="123"
int_number = int(str_number)
float_number = float(str_number)
print(f"original:{str_number}(type:{type(str_number)})")
print(f"converted:{int_number}(type:{type(int_number)})")
print(f"converted:{float_number}(type:{type(float_number)})")
# Out:
# original:123(type:<class 'str'>)
# converted:123(type:<class 'int'>)
# converted:123.0(type:<class 'float'>)

# %% [markdown]
# personal information

# %%
first_name="kushal"
last_name="choudhary"
age=20
heigth=5.7
is_student=True

# %% [markdown]
# print formatted information

# %%
print(f"first name:{first_name}")
print(f"last name:{last_name}")
print(f"age:{age}")
print(f"heigth:{heigth}")
print(f"is student:{is_student}")
# Out:
# first name:kushal
# last name:choudhary
# age:20
# heigth:5.7
# is student:True

# %% [markdown]
# type conversion

# %%
age_str = str(age)
heigth_int = int(heigth)
print(f"age as string: {age_str}")
print(f"heigth as integer: {heigth_int}")
# Out:
# age as string: 20
# heigth as integer: 5

# %% [markdown]
# operators and basic operators

# %%
a =10
b=20
print(f"addition:{a}+{b}={a+b}")
print(f"subtraction:{a}-{b}={a-b}")
print(f"multiplication:{a}*{b}={a*b}")
print(f"division:{a}/{b}={a/b}")
print(f"modulus:{a}%{b}={a%b}")
print(f"exponentiation:{a}**{b}={a**b}")
# Out:
# addition:10+20=30
# subtraction:10-20=-10
# multiplication:10*20=200
# division:10/20=0.5
# modulus:10%20=10
# exponentiation:10**20=100000000000000000000

# %% [markdown]
# order of operations(PEMDAS)
# - P - parentheses
# - E - exponents
# - M - multiplication
# - D - division
# - A - addition
# - S - subraction

# %%
result = 2 + 3 * 4 ** 2 - 1
print(f"2 + 3 * 4 ** 2 - 1 = {result}")
# Out:
# 2 + 3 * 4 ** 2 - 1 = 49

# %%
x= 5
y= 10
print(f"{x} == {y}: {x == y}")
print(f"{x} != {y}: {x != y}")
print(f"{x} > {y}: {x > y}")
print(f"{x} < {y}: {x < y}")
print(f"{x}>= {y}: {x >= y}")
print(f"{x} <= {y}: {x <= y}")
# Out:
# 5 == 10: False
# 5 != 10: True
# 5 > 10: False
# 5 < 10: True
# 5>= 10: False
# 5 <= 10: True

# %% [markdown]
# string comparision

# %%
name1 = "alice"
name2 = "bob"
print(f"'{name1}' < '{name2}': {name1 < name2}")
print(f"'{name1}' > '{name2}': {name1 > name2}")
# Out:
# 'alice' < 'bob': True
# 'alice' > 'bob': False

# %% [markdown]
# logical operators

# %%
p=True
q=False
print(f"p and q: {p and q}")
print(f"p or q: {p or q}")
print(f"not p: {not p}")
# Out:
# p and q: False
# p or q: True
# not p: False

# %%
# practical example
age = 20
has_license = True
can_drive = age >= 18 and has_license
print(f"can drive: {can_drive}")
# Out:
# can drive: True

# %%
# multiple conditions
score = 85
is_present = True
can_pass =score >= 80 and is_present
print(f"can pass: {can_pass}")
# Out:
# can pass: True

# %% [markdown]
# hands-on exercise

# %%
# PERSONAL INFORMATION
age =25
annul_income = 50000
credit_score = 720
has_collateral = True

# %%
# lone criteria
min_age = 18
min_income = 30000
min_credit_score = 650

# %%
# check qualifications
age_qualified = age >= min_age
income_qualified = annul_income >= min_income
credit_score_qualified = credit_score >= min_credit_score
overall_qualified = age_qualified and income_qualified and credit_score_qualified

# %%
print("=== loan qualification check ===")
print(f"age: {age_qualified}")
print(f"annul income: {income_qualified}")
print(f"credit score: {credit_score_qualified}")
print(f"overall qualification: {overall_qualified}")
# Out:
# === loan qualification check ===
# age: True
# annul income: True
# credit score: True
# overall qualification: True

# %% [markdown]
# creating lists

# %%
fruits = ["apple","banana","orange","grape"]
numbers =[10,20,30,40,50]
mixed_data =[1,"hello",3.14,True]

# %% [markdown]
# list indexing (0-based)

# %%
print(f"first fruit: {fruits[0]}")
print(f"second fruit: {fruits[1]}")
print(f"third fruit: {fruits[2]}")
print(f"fourth fruit: {fruits[3]}")
print(f"last fruit: {fruits[-1]}")
# Out:
# first fruit: apple
# second fruit: banana
# third fruit: orange
# fourth fruit: grape
# last fruit: grape

# %% [markdown]
# list slicing

# %%
print(f"first 2 fruits: {fruits[0:2]}")
print(f"last 2 fruits: {fruits[-2:]}")
print(f"all except first: {fruits[1:]}")
# Out:
# first 2 fruits: ['apple', 'banana']
# last 2 fruits: ['orange', 'grape']
# all except first: ['banana', 'orange', 'grape']

# %% [markdown]
# list methodes

# %%
fruits.append("kiwi")
fruits.insert(1,"strawberry")
removed = fruits.pop(2)
print(f"removed fruit: {removed}")
print(f"updated fruits: {fruits}")
# Out:
# removed fruit: banana
# updated fruits: ['apple', 'strawberry', 'orange', 'grape', 'kiwi']

# %% [markdown]
# list operations

# %%
print("length: {len(fruits)}")
print(f"contains apple: {'apple' in fruits}")
print(f"Index of 'banana': {fruits.index('banana')}")
# Out:
# length: {len(fruits)}
# contains apple: True
# Index of 'banana': 1

# %% [markdown]
# tuples are immutable

# %%
coordinates =(10,20)
rgb_color =(255,128,0)
person_info =("alice",25,"engineer",True)

# %% [markdown]
# tuple unpacking

# %%
x,y = coordinates
print(f"x: {x},y:{y}")
# Out:
# x: 10,y:20

# %% [markdown]
# tuple methods

# %%
print(f"count of 25: {person_info.count(25)}")
print(f"index of 'engineer': {person_info.index('engineer')}")
# Out:
# count of 25: 1
# index of 'engineer': 2

# %% [markdown]
# basic for loop

# %%
fruits=["apple","banana","orange"]
for fruit in fruits:
    print(f"I like {fruit}")
# Out:
# I like apple
# I like banana
# I like orange

# %% [markdown]
# loop with range

# %%
for day in range(1,8):
  print(f"day:{day} of the week")
# Out:
# day:1 of the week
# day:2 of the week
# day:3 of the week
# day:4 of the week
# day:5 of the week
# day:6 of the week
# day:7 of the week

# %% [markdown]
# nested loops-creating a multiplaction table

# %%
print("multiplication table:")
for i in range(1,6):
    print(f"table for {i}:")
    for j in range(1,6):
        print(f"{i} x {j} = {i*j}")
# Out:
# multiplication table:
# table for 1:
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# table for 2:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# table for 3:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# table for 4:
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# table for 5:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25

# %% [markdown]
# PROCESSING DATA WITH LOOP

# %%
sales_data=[
 {"product":"laptop","price":999,"quantity":5},
{"product":"phone","price":599,"quantity":10},
{"product":"tablet","price":399,"quantity":8}
]
total_revenue=0
for item in sales_data:
    revenue = item["price"] * item["quantity"]
    total_revenue += revenue
    print(f"revenue for {item['product']}: ${revenue}")
print(f"total revenue: ${total_revenue}")
# Out:
# revenue for laptop: $4995
# revenue for phone: $5990
# revenue for tablet: $3192
# total revenue: $14177

# %% [markdown]
# loops-while loop

# %% [markdown]
# while loop for user input simulation

# %%
def simple_gussing_game():
  target=7
  guss=0
  attempts=0
  print("guess the number between 1 and 10")
  while guss != target:

    import random
    guss = rendom.randint(1,10)
    attempts +=1
    if guess< target:
      print(f"guss{attempts}:{guess}-too low!")
    elif guess > target:
      print(f"guess{attempts}:{guess}-too high!")
    else:
        print(f"guess{attempts}:{guess}-correct!")

        if attempts>10:
          print("max attempts reached")
          break
          print(f"gussing game completed in {attempts} attempts")
          simple_gussing_game()

# %% [markdown]
# while loop for processesing

# %%
def process_queue():
  queue= ["task 1","task 2","task 3","task 4"]
  while queue:
    current_task =queue.pop(0)
    print(f"processing:{current_task}")
    print(f"remaining tasks:{queue}")
    print("queue processing completed")
    process_queue()

# %% [markdown]
# basic function definition

# %%
def greet(name):
  return f"hello,{name}!"

# %% [markdown]
# function with multiple paramenters

# %%
def calcualte_area(length,width):
  area= length*width
  return area

# %% [markdown]
# test the function

# %%
room_area = calcualte_area(5,10)
print(f"room area:{room_area}")
# Out:
# room area:50

# %% [markdown]
# function with default parameters

# %%
def create_user_profile(name,age=18, location="unknown",active=True):
 return{
    "name":name,
    "age":age,
    "location":location,
    "active":active
}

# %% [markdown]
# different ways to call

# %%
profile1=create_user_profile("alice")
profile2=create_user_profile("bob",25,"new york")
profile3=create_user_profile("charlie",location="london",age=30)
print(f"Profile1:{profile1}")
print(f"Profile2:{profile2}")
print(f"Profile3:{profile3}")
# Out:
# Profile1:{'name': 'alice', 'age': 18, 'location': 'unknown', 'active': True}
# Profile2:{'name': 'bob', 'age': 25, 'location': 'new york', 'active': True}
# Profile3:{'name': 'charlie', 'age': 30, 'location': 'london', 'active': True}

# %% [markdown]
# function returning multiple values

# %%
def analyze_text(text):
  words =text.split()
  word_count =len(words)
  char_count =len(text)
  char_count_no_spaces =len(text.replace(" ",""))
  return word_count,char_count,char_count_no_spaces

# %% [markdown]
# test with sample text

# %%
sample_text="python is a powerful programming language"
words,chars,chars_no_space =analyze_text(sample_text)
print(f"text:{sample_text},words:{words},chars:{chars},chars_no_space:{chars_no_space}")
# Out:
# text:python is a powerful programming language,words:6,chars:41,chars_no_space:36

# %% [markdown]
# variable length arguments

# %%
def calcualte_arerage(*numbers):
  if not numbers:
    return 0
    return sum(numbers)/len(numbers)

# %% [markdown]
# test with different numbers of arguments

# %%
avg1=calcualte_arerage(10,20,30)
avg2=calcualte_arerage(5,15,25,35,45)
avg3=calcualte_arerage(100)
print(f"avg1:{avg1},avg2:{avg2},avg3:{avg3}")
# Out:
# avg1:None,avg2:None,avg3:None

# %% [markdown]
# keyword arguments

# %%
def create_report(**data):
  print("===report===")
  for key,value in data.items():
    print(f"{key.replace('_',' ').title()}:{value}")
    print("===========")
    create_report(
        title="montly sales report",
        date="2024-01-01",
        total_sales=15000,
        new_customers=50,
        returning_customer=150
    )

# %% [markdown]
# lambda function

# %%
def square(x):
  return x ** 2

# %% [markdown]
# lambda equivalent

# %%
square_lambda = lambda x:x ** 2
print(f"regular function:{square(5)}")
print(f"lambda function:{square_lambda(5)}")
# Out:
# regular function:25
# lambda function:25

# %%
people =[
    {"name":"alice","age":30},
    {"name":"bob","age":25},
    {"name":"charlie","age":35}

]
sorted_people =sorted(people,key=lambda person:person["age"])
print(f"sorted people:{sorted_people}")
for person in sorted_people:
  print(f"{person['name']}:{person['age']}")
# Out:
# sorted people:[{'name': 'bob', 'age': 25}, {'name': 'alice', 'age': 30}, {'name': 'charlie', 'age': 35}]
# bob:25
# alice:30
# charlie:35

# %% [markdown]
# line plot

# %%
import matplotlib.pyplot as plt
years=[2019,2020,2021,2022]
revenue=[100,120,130,160]
plt.plot(years,revenue,marker='o',linestyle='-')
plt.title("company revenue over years")
plt.xlabel("year")
plt.ylabel("revenue")
plt.grid(True)
plt.show()

# %% [markdown]
# bar chat

# %%
departments= df['department'].value_counts()
departments.plot(kind='bar',color='tela')
plt.title("employee count")
plt.xlabel("department")
plt.ylabel("count")
plt.show()

# %%
import pandas as pd
import numpy as np # Import numpy for generating random ages

# Create a dummy DataFrame with 'department' and 'age' columns
data = {'department': ['Sales', 'Marketing', 'IT', 'Sales', 'IT', 'Marketing', 'Sales'],
        'age': np.random.randint(20, 60, size=7)} # Add a dummy 'age' column with random ages

df = pd.DataFrame(data)

# Display the first few rows of the dummy DataFrame
display(df.head())
# Out:
#   department  age
# 0      Sales   52
# 1  Marketing   41
# 2         IT   30
# 3      Sales   38
# 4         IT   43

# %% [markdown]
# hestogram

# %%
ages = df['age']
plt.hist(ages, bins=10, color='yellow',edgecolor='black')
plt.title("age distribution")
plt.xlabel("age")
plt.ylabel("count")
plt.show()

# %% [markdown]
# pie chart

# %%
from enum import auto
df.groupby('department').size().plot(kind='pie',autopct='%1.1f%%',colors=['red','green','blue'])
plt.title("department distribution")
plt.ylabel("")
plt.show()

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['sex'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['total_bill'].plot(kind='hist', bins=20, title='total_bill')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['tip'].plot(kind='hist', bins=20, title='tip')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['size'].plot(kind='hist', bins=20, title='size')
# ...

# %%
sns.boxplot(x="day",y="total_bill",data=tips)
plt.title("total bill by day")
plt.show()

# %%
print("\n info about the tips dataset:")
tips.info()
print("\n description of the tips dataset:")
print(tips.describe(include='all')) # Explicitly print to avoid quickchart plotting
# Out:
#  info about the tips dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
#
#  description of the tips dataset:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# ...

# %%
sns.pairplot(tips,hue='sex')
plt.show()

# %%
corr=tips.corr(numeric_only=True)
sns.hearmap(corr,annot=True,cmap='coolwarm')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-557560558.py in <cell line: 0>()
# ----> 1 corr=tips.corr(numeric_only=True)
#       2 sns.hearmap(corr,annot=True,cmap='coolwarm')
#       3 plt.show()
#
# NameError: name 'tips' is not defined

# %%
sns.countplot(data=tips,x='day',hue='sex')
plt.show()

# %%
sns.boxplot(x='day',y='total_bill',data=tips)
plt.show()

# %% [markdown]
# # data preprocessing in python
# **why data preprocessing **
# - it can have missing values, wrong formats, different scales or categories that need conversion

# %% [markdown]
# handling missing data

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
# pd.set_option("display.max_rows",none)
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.drop(columns=['Cabin'],inplace=True)

# %%
df['Embarked'].fillna('unknown',inplace=True)
# Out:
# /tmp/ipython-input-1936160088.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna('unknown',inplace=True)

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
# Re-load the dataset to ensure the DataFrame is correct
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
# Now try running the cell with the error again
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.drop(columns=['Cabin'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Sex'] = le.fit_transform(df['Sex'])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
df= pd.get_dummies(df,columns=['Embarked'],drop_first=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %% [markdown]
# load and inspect data

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/insurance.csv')
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['bmi'].plot(kind='hist', bins=20, title='bmi')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['children'].plot(kind='hist', bins=20, title='children')
# ...

# %% [markdown]
# check for null values

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# one-hot encode categorical variables

# %%
df_encoded = pd.get_dummies(df,drop_first=True)
df_encoded.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400     False        True             False
# 1   18  33.770         1   1725.55230      True       False             False
# 2   28  33.000         3   4449.46200      True       False             False
# 3   33  22.705         0  21984.47061      True       False              True
# 4   32  28.880         0   3866.85520      True       False              True
#
#    region_southeast  region_southwest
# 0             False              True
# 1              True             False
# 2              True             False
# 3             False             False
# 4             False             False
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_20['age'].plot(kind='hist', bins=20, title='age')
# ...

# %% [markdown]
# feature and target separation

# %%
x =df_encoded.drop('charges',axis=1)
y = df_encoded['charges']

# %% [markdown]
# feature scaling using standardscaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %% [markdown]
# train test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.2,random_state=42)

# %% [markdown]
# train linear regression model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# make predictions

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score
import numpy as np
mse = mean_squared_error(y_test,y_pred)
r2mse = np.sqrt(mse)
print(f"mean squared error:{mse}")
print(f"root mean squared error:{r2mse}")
print(f"r2 score:{r2_score(y_test,y_pred)}")
# Out:
# mean squared error:33596915.85136148
# root mean squared error:5796.284659276275
# r2 score:0.7835929767120722
